# %% [markdown]
# <a href="https://colab.research.google.com/github/TIFFANYspr/Inteligencia_Artificial/blob/main/Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
productos = [
    {"Producto": "Laptop", "Precio": 3500000, "Cantidad": 4, "Costo_Envio": 50000, "Categoria": "Tecnología"},
    {"Producto": "Mouse", "Precio": 80000, "Cantidad": 15, "Costo_Envio": 10000, "Categoria": "Tecnología"},
    {"Producto": "Teclado", "Precio": 120000, "Cantidad": 10, "Costo_Envio": 12000, "Categoria": "Tecnología"},
    {"Producto": "Silla Gamer", "Precio": 450000, "Cantidad": 5, "Costo_Envio": 30000, "Categoria": "Tecnología"},
    {"Producto": "Escritorio Gamer", "Precio": 900000, "Cantidad": 3, "Costo_Envio": 40000, "Categoria": "Tecnología"},
    {"Producto": "Monitor", "Precio": 1100000, "Cantidad": 6, "Costo_Envio": 35000, "Categoria": "Tecnología"},
    {"Producto": "Impresora", "Precio": 650000, "Cantidad": 7, "Costo_Envio": 25000, "Categoria": "Tecnología"},
    {"Producto": "Cámara Web", "Precio": 180000, "Cantidad": 12, "Costo_Envio": 15000, "Categoria": "Tecnología"},
    {"Producto": "Disco Duro Externo", "Precio": 320000, "Cantidad": 8, "Costo_Envio": 18000, "Categoria": "Tecnología"},
    {"Producto": "Memoria USB", "Precio": 45000, "Cantidad": 25, "Costo_Envio": 8000, "Categoria": "Tecnología"},
    {"Producto": "Tablet", "Precio": 980000, "Cantidad": 5, "Costo_Envio": 28000, "Categoria": "Tecnología"},
    {"Producto": "Celular Samsung", "Precio": 2200000, "Cantidad": 9, "Costo_Envio": 30000, "Categoria": "Tecnología"},
    {"Producto": "Celular iPhone", "Precio": 5200000, "Cantidad": 4, "Costo_Envio": 40000, "Categoria": "Tecnología"},
    {"Producto": "Audífonos Bluetooth", "Precio": 150000, "Cantidad": 20, "Costo_Envio": 10000, "Categoria": "Tecnología"},
    {"Producto": "Parlante Bluetooth", "Precio": 210000, "Cantidad": 10, "Costo_Envio": 12000, "Categoria": "Tecnología"},
    {"Producto": "Smartwatch", "Precio": 350000, "Cantidad": 11, "Costo_Envio": 15000, "Categoria": "Tecnología"},
    {"Producto": "Router WiFi", "Precio": 270000, "Cantidad": 6, "Costo_Envio": 14000, "Categoria": "Tecnología"},
    {"Producto": "Cable HDMI", "Precio": 35000, "Cantidad": 30, "Costo_Envio": 5000, "Categoria": "Tecnología"},
    {"Producto": "Micrófono USB", "Precio": 190000, "Cantidad": 7, "Costo_Envio": 12000, "Categoria": "Tecnología"},
    {"Producto": "Tarjeta Gráfica", "Precio": 1800000, "Cantidad": 3, "Costo_Envio": 35000, "Categoria": "Tecnología"},
    {"Producto": "Procesador Intel", "Precio": 1400000, "Cantidad": 4, "Costo_Envio": 30000, "Categoria": "Tecnología"},
    {"Producto": "Memoria RAM 16GB", "Precio": 280000, "Cantidad": 15, "Costo_Envio": 10000, "Categoria": "Tecnología"},
    {"Producto": "Fuente de Poder", "Precio": 320000, "Cantidad": 9, "Costo_Envio": 12000, "Categoria": "Tecnología"},
    {"Producto": "SSD 1TB", "Precio": 450000, "Cantidad": 10, "Costo_Envio": 15000, "Categoria": "Tecnología"},
    {"Producto": "Cámara Digital", "Precio": 2500000, "Cantidad": 2, "Costo_Envio": 45000, "Categoria": "Tecnología"},
    {"Producto": "Drone", "Precio": 3200000, "Cantidad": 3, "Costo_Envio": 50000, "Categoria": "Tecnología"},
    {"Producto": "Consola PS5", "Precio": 3100000, "Cantidad": 5, "Costo_Envio": 40000, "Categoria": "Tecnología"},
    {"Producto": "Xbox Series X", "Precio": 2900000, "Cantidad": 4, "Costo_Envio": 40000, "Categoria": "Tecnología"},
    {"Producto": "Nintendo Switch", "Precio": 1800000, "Cantidad": 6, "Costo_Envio": 30000, "Categoria": "Tecnología"},
    {"Producto": "Mouse Pad RGB", "Precio": 70000, "Cantidad": 18, "Costo_Envio": 7000, "Categoria": "Tecnología"},
    {"Producto": "Proyector", "Precio": 1500000, "Cantidad": 4, "Costo_Envio": 35000, "Categoria": "Tecnología"},
    {"Producto": "Scanner", "Precio": 420000, "Cantidad": 5, "Costo_Envio": 18000, "Categoria": "Tecnología"},
    {"Producto": "Regulador de Voltaje", "Precio": 130000, "Cantidad": 9, "Costo_Envio": 10000, "Categoria": "Tecnología"},
    {"Producto": "UPS", "Precio": 550000, "Cantidad": 6, "Costo_Envio": 20000, "Categoria": "Tecnología"},
    {"Producto": "Lámpara LED USB", "Precio": 45000, "Cantidad": 14, "Costo_Envio": 6000, "Categoria": "Tecnología"},
    {"Producto": "Webcam HD", "Precio": 220000, "Cantidad": 7, "Costo_Envio": 12000, "Categoria": "Tecnología"},
    {"Producto": "Tablet Gráfica", "Precio": 680000, "Cantidad": 5, "Costo_Envio": 18000, "Categoria": "Tecnología"},
    {"Producto": "Smart TV 50", "Precio": 2800000, "Cantidad": 3, "Costo_Envio": 45000, "Categoria": "Tecnología"},
    {"Producto": "Smart TV 32", "Precio": 1400000, "Cantidad": 5, "Costo_Envio": 35000, "Categoria": "Tecnología"},
    {"Producto": "Aire Acondicionado Inteligente", "Precio": 3500000, "Cantidad": 2, "Costo_Envio": 60000, "Categoria": "Tecnología"},
    {"Producto": "Alexa Echo Dot", "Precio": 280000, "Cantidad": 8, "Costo_Envio": 12000, "Categoria": "Tecnología"},
    {"Producto": "Google Chromecast", "Precio": 190000, "Cantidad": 12, "Costo_Envio": 10000, "Categoria": "Tecnología"},
    {"Producto": "Cámara de Seguridad", "Precio": 350000, "Cantidad": 10, "Costo_Envio": 15000, "Categoria": "Tecnología"},
    {"Producto": "Timbre Inteligente", "Precio": 420000, "Cantidad": 4, "Costo_Envio": 18000, "Categoria": "Tecnología"},
    {"Producto": "Disco SSD 500GB", "Precio": 260000, "Cantidad": 11, "Costo_Envio": 12000, "Categoria": "Tecnología"},
    {"Producto": "Laptop Gamer", "Precio": 5800000, "Cantidad": 3, "Costo_Envio": 50000, "Categoria": "Tecnología"},
    {"Producto": "MacBook Air", "Precio": 6200000, "Cantidad": 2, "Costo_Envio": 55000, "Categoria": "Tecnología"},
    {"Producto": "Teclado Mecánico", "Precio": 280000, "Cantidad": 9, "Costo_Envio": 12000, "Categoria": "Tecnología"},
    {"Producto": "Mouse Gamer", "Precio": 160000, "Cantidad": 13, "Costo_Envio": 10000, "Categoria": "Tecnología"},
    {"Producto": "Silla Ergonómica", "Precio": 780000, "Cantidad": 4, "Costo_Envio": 30000, "Categoria": "Tecnología"},
    {"Producto": "Hub USB", "Precio": 90000, "Cantidad": 20, "Costo_Envio": 7000, "Categoria": "Tecnología"},
    {"Producto": "Cargador Inalámbrico", "Precio": 120000, "Cantidad": 15, "Costo_Envio": 9000, "Categoria": "Tecnología"},
    {"Producto": "Power Bank", "Precio": 180000, "Cantidad": 10, "Costo_Envio": 10000, "Categoria": "Tecnología"},
    {"Producto": "Gafas VR", "Precio": 2400000, "Cantidad": 3, "Costo_Envio": 45000, "Categoria": "Tecnología"},
    {"Producto": "Proyector Portátil", "Precio": 980000, "Cantidad": 5, "Costo_Envio": 25000, "Categoria": "Tecnología"},
    {"Producto": "Impresora 3D", "Precio": 3200000, "Cantidad": 2, "Costo_Envio": 50000, "Categoria": "Tecnología"},
    {"Producto": "Cámara GoPro", "Precio": 2100000, "Cantidad": 4, "Costo_Envio": 35000, "Categoria": "Tecnología"},
    {"Producto": "Smart Band", "Precio": 150000, "Cantidad": 16, "Costo_Envio": 10000, "Categoria": "Tecnología"},
    {"Producto": "Mini PC", "Precio": 1750000, "Cantidad": 5, "Costo_Envio": 30000, "Categoria": "Tecnología"},
    {"Producto": "Docking Station", "Precio": 350000, "Cantidad": 7, "Costo_Envio": 15000, "Categoria": "Tecnología"}
]
