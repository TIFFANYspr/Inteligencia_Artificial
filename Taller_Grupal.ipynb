# %% [markdown]
# <a href="https://colab.research.google.com/github/TIFFANYspr/Inteligencia_Artificial/blob/main/Taller_Grupal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="border:2px solid black; padding:15px;">
#
#  #  <b> Universidad Del Pacifico  </b>
#
#  <img src="https://github.com/wilmanAQ/Inteligencia_Artificial/blob/IA/icono_unipacifico.jpeg?raw=1" width="100">
#   <img src="https://github.com/wilmanAQ/Inteligencia_Artificial/blob/IA/icono_PIS.png?raw=1" width="270">
#
#
# # <b> Taller Práctico de Pandas y Operaciones Matemáticas </b>
#
# ## <b> Estudiantes: </b>
# Stefany Potosi Reyes <br>
# Angel Santiago Estupiñán Gomez <br>
# Cristian Valderrama
# Suarez
#
# ## <b> Materia: </b>
# Inteligencia Artificial
#
# ## <b> Tema: </b>
# Manejo de DataFrames con Pandas
#
# ## <b> Objetivo de este taller: </b>
# Aplicar operaciones matemáticas, estadísticas y análisis de datos utilizando Python y Pandas, con ayuda de Colab .
#
# </div>

# %% [markdown]
# # <b> PUNTO 1 - CREACION Y EXPLORACION DEL DATAFRAME </b>
#
# ## <b> Importamos Librerías </b>
#
# Importamos las librerías necesarias para trabajar con análisis de datos utilizando Python y Pandas.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## <b> Crear el DataFrame </b>
#
# Aqui creamos el DataFrame utilizando  Pandas y los datos proporcionados y pedidos en el taller y subidos al GitHub.

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/TIFFANYspr/Inteligencia_Artificial/570a982b63ac7c7ccabbe7726dc6b80570cb66e8/CORTE%202/TALLER%202/productos_tecnologia_60.csv"

df = pd.read_csv(url, sep=";")

print(df)
# Out:
#                           Producto   Precio  Cantidad  Costo_Envio   Categoria
# 0                           Laptop  3500000         4        50000  Tecnología
# 1                            Mouse    80000        15        10000  Tecnología
# 2                          Teclado   120000        10        12000  Tecnología
# 3                      Silla Gamer   450000         5        30000  Tecnología
# 4                 Escritorio Gamer   900000         3        40000  Tecnología
# 5                          Monitor  1100000         6        35000  Tecnología
# 6                        Impresora   650000         7        25000  Tecnología
# 7                       Cámara Web   180000        12        15000  Tecnología
# 8               Disco Duro Externo   320000         8        18000  Tecnología
# 9                      Memoria USB    45000        25         8000  Tecnología
# 10                          Tablet   980000         5        28000  Tecnología
# ...

# %% [markdown]
# ## <b> Mostrar las primeras 5 filas </b>
#
# Se utiliza el método head() para visualizar los primeros 5 registros del DataFrame.

# %%
primeros = df.head(5)

print("Primeros 5 registros:")
print(primeros)
# Out:
# Primeros 5 registros:
#            Producto   Precio  Cantidad  Costo_Envio   Categoria
# 0            Laptop  3500000         4        50000  Tecnología
# 1             Mouse    80000        15        10000  Tecnología
# 2           Teclado   120000        10        12000  Tecnología
# 3       Silla Gamer   450000         5        30000  Tecnología
# 4  Escritorio Gamer   900000         3        40000  Tecnología

# %% [markdown]
# ## <b> Mostrar las últimas 10 filas </b>
#
# Se utiliza tail() para visualizar los últimos registros del DataFrame.

# %%
ultimos = df.tail(10)

print("Últimos 10 registros:")
print(ultimos)
# Out:
# Últimos 10 registros:
#                 Producto   Precio  Cantidad  Costo_Envio   Categoria
# 50               Hub USB    90000        20         7000  Tecnología
# 51  Cargador Inalámbrico   120000        15         9000  Tecnología
# 52            Power Bank   180000        10        10000  Tecnología
# 53              Gafas VR  2400000         3        45000  Tecnología
# 54    Proyector Portátil   980000         5        25000  Tecnología
# 55          Impresora 3D  3200000         2        50000  Tecnología
# 56          Cámara GoPro  2100000         4        35000  Tecnología
# 57            Smart Band   150000        16        10000  Tecnología
# 58               Mini PC  1750000         5        30000  Tecnología
# 59       Docking Station   350000         7        15000  Tecnología

# %% [markdown]
# ## <b> Mostrar el tipo de dato de cada columna </b>
#
# Se utiliza dtypes para identificar el tipo de dato de cada columna.

# %%
tipos_datos = df.dtypes

print("Tipos de datos:")
print(tipos_datos)
# Out:
# Tipos de datos:
# Producto       object
# Precio          int64
# Cantidad        int64
# Costo_Envio     int64
# Categoria      object
# dtype: object

# %% [markdown]
# ##<b> Mostrar el tamaño del DataFrame (Filas y columnas) </b>
#
# La función shape permite conocer la cantidad de filas y columnas dentro del DataFrame.

# %%
Fila,Columnas = df.shape

print("Cantidad de filas:", Fila)
print("Cantidad de columnas:", Columnas)
# Out:
# Cantidad de filas: 60
# Cantidad de columnas: 5

# %% [markdown]
# ## <b> Generar una descripción estadística del conjunto de los datos </b>
#
# Se utiliza describe() para obtener estadísticas generales del DataFrame.

# %%
descripcion_estadistica = df.describe()

print("Descripción estadística:")
print(descripcion_estadistica)
# Out:
# Descripción estadística:
#              Precio   Cantidad   Costo_Envio
# count  6.000000e+01  60.000000     60.000000
# mean   1.200583e+06   8.316667  24033.333333
# std    1.474422e+06   5.843993  15000.527298
# min    3.500000e+04   2.000000   5000.000000
# 25%    1.900000e+05   4.000000  12000.000000
# 50%    4.350000e+05   6.500000  18000.000000
# 75%    1.800000e+06  10.250000  35000.000000
# max    6.200000e+06  30.000000  60000.000000

# %% [markdown]
# # <b> PUNTO 2 — OPERACIONES MATEMÁTICAS </b>
#
# En esta sección se crearan nuevas columnas utilizando operaciones matemáticas.
#
# ## <b> Crear columna Total_Venta </b>
#
# Se multiplica el precio por la cantidad para calcular el total vendido por producto.
# Total_Venta = Precio × Cantidad

# %%
df["Total_Venta"] = df["Precio"] * df["Cantidad"]

print(df[["Producto", "Total_Venta"]].head())
# Out:
#            Producto  Total_Venta
# 0            Laptop     14000000
# 1             Mouse      1200000
# 2           Teclado      1200000
# 3       Silla Gamer      2250000
# 4  Escritorio Gamer      2700000

# %% [markdown]
# ## <b> Crear columna Costo_Total </b>
#
# Se suma el Total_Venta más el costo de envío.
#
# Costo_Total=Total_Venta+Costo_Envio

# %%
df["Costo_Total"] = df["Total_Venta"] + df["Costo_Envio"]

print(df[["Producto", "Costo_Total"]].head())
# Out:
#            Producto  Costo_Total
# 0            Laptop     14050000
# 1             Mouse      1210000
# 2           Teclado      1212000
# 3       Silla Gamer      2280000
# 4  Escritorio Gamer      2740000

# %% [markdown]
# ## <b> Promedio de Total_Venta </b>
#
# Se calcula el promedio de ventas utilizando mean().

# %%
promedio_ventas = df["Total_Venta"].mean()

print("El promedio total de las ventas es:", promedio_ventas)
# Out:
# Promedio de Total_Venta: 5160916.666666667

# %% [markdown]
# ## <b> Producto con mayor Total_Venta </b>
#
# Se identifica el producto con mayores ventas utilizando idxmax().

# %%
produto_mayor_venta = df.loc[df["Total_Venta"].idxmax()]

print("El producto con mayor venta es:")
print(produto_mayor_venta)
# Out:
# El producto con mayor venta es:
# Producto       Celular iPhone
# Precio                5200000
# Cantidad                    4
# Costo_Envio             40000
# Categoria          Tecnología
# Total_Venta          20800000
# Costo_Total          20840000
# Name: 12, dtype: object

# %% [markdown]
# ## <b> Producto con menor Total_Venta </b>
#
# Se identifica el producto con menores ventas utilizando idxmin().

# %%
producto_menor_venta = df.loc[df["Total_Venta"].idxmin()]

print("El producto con menor venta es:")
print(producto_menor_venta)
# Out:
# El producto con menor venta es:
# Producto       Lámpara LED USB
# Precio                   45000
# Cantidad                    14
# Costo_Envio               6000
# Categoria           Tecnología
# Total_Venta             630000
# Costo_Total             636000
# Name: 34, dtype: object

# %% [markdown]
# # <b> PUNTO 3 — PORCENTAJES Y ANÁLISIS </b>
#
# En esta sección se realizan cálculos de porcentajes relacionados con las ventas.
#
#
# ## <b>Crear columna IVA</b>
#
# Se calcula el 19% del Total_Venta.
#
# IVA = Total_Venta X 0.19

# %%
df["IVA"] = df["Total_Venta"] * 0.19

print(df[["Producto", "IVA"]].head())
# Out:
#            Producto        IVA
# 0            Laptop  2660000.0
# 1             Mouse   228000.0
# 2           Teclado   228000.0
# 3       Silla Gamer   427500.0
# 4  Escritorio Gamer   513000.0

# %% [markdown]
# ## <b> Crear columna Ganancia_Estimada </b>
#
# Se calcula una ganancia estimada del 25%.
#
# Ganancia_Estimada = Total_Venta X 0.25

# %%
df["Ganancia_Estimada"] = df["Total_Venta"] * 0.25

print(df[["Producto", "Ganancia_Estimada"]].head())
# Out:
#            Producto  Ganancia_Estimada
# 0            Laptop          3500000.0
# 1             Mouse           300000.0
# 2           Teclado           300000.0
# 3       Silla Gamer           562500.0
# 4  Escritorio Gamer           675000.0

# %% [markdown]
# ## <b> Crear columna Perdida_Estimada </b>
#
# Se calcula una pérdida estimada del 0.05%.
#
# Perdida_Estimada = Total_Venta X 0.0005

# %%
df["Perdida_Estimada"] = df["Total_Venta"] * 0.0005

print(df[["Producto", "Perdida_Estimada"]].head())
# Out:
#            Producto  Perdida_Estimada
# 0            Laptop            7000.0
# 1             Mouse             600.0
# 2           Teclado             600.0
# 3       Silla Gamer            1125.0
# 4  Escritorio Gamer            1350.0

# %% [markdown]
# ## <B>Calcular porcentaje de ventas</B>
#
# Se calcula qué porcentaje representa cada producto respecto al total general.
#
# Porcentaje_Ventas = (Total_Venta/Total General)​ X 100

# %%
total_general = df["Total_Venta"].sum()

df["Porcentaje_Ventas"] = (df["Total_Venta"] / total_general) * 100

print(df[["Producto", "Porcentaje_Ventas"]].head())
# Out:
#            Producto  Porcentaje_Ventas
# 0            Laptop           4.521161
# 1             Mouse           0.387528
# 2           Teclado           0.387528
# 3       Silla Gamer           0.726615
# 4  Escritorio Gamer           0.871938

# %% [markdown]
# ## <b>Filtrar productos con porcentaje superior al 15% </b>
#
# Se muestran únicamente los productos cuyo porcentaje sea mayor al 15%.

# %%
productos_mayor_15 = df[df["Porcentaje_Ventas"] > 15]

print(productos_mayor_15)
# Out:
# Empty DataFrame
# Columns: [Producto, Precio, Cantidad, Costo_Envio, Categoria, Total_Venta, Costo_Total, IVA, Ganancia_Estimada, Perdida_Estimada, Porcentaje_Ventas]
# Index: []

# %% [markdown]
# # <B> PUNTO 4 _ ESTADÍSTICA DESCRIPTIVA </B>
#
# En esta sección se calculan diferentes medidas estadísticas para analizar el comportamiento de los datos.
#
# ## <B> Calcular la media de la columna Precio </B>
#
# La media representa el promedio de todos los precios registrados en el DataFrame.
#
# Media = ∑x ​/ n

# %%
media = df["Precio"].mean()

print("La media del precio es:", media)
# Out:
# La media del precio es: 1200583.3333333333

# %% [markdown]
# ## <B> Calcular la mediana de la columna Precio </B>
#
# La mediana representa el valor central de todos los precios ordenados.

# %%
mediana = df["Precio"].median()

print("La mediana del precio es:", mediana)
# Out:
# La mediana del precio es: 435000.0

# %% [markdown]
# ## <B> Calcular la moda de la columna Precio </B>
#
# La moda representa el valor que más se repite dentro de la columna Precio.

# %%
moda = df["Precio"].mode()

print("La moda del precio es:", moda)

print(moda)
# Out:
# La moda del precio es: 0    280000
# 1    350000
# Name: Precio, dtype: int64
# 0    280000
# 1    350000
# Name: Precio, dtype: int64

# %% [markdown]
# ## <b> Calcular desviación estándar de Cantidad </b>
#
# La desviación estándar mide qué tan dispersos están los datos respecto al promedio.
#
# σ = √(Σ(x - μ)² / N)

# %%
desviacion = df["Cantidad"].std()

print("La desviación estándar es:", desviacion)
# Out:
# La desviación estándar es: 5.843993487933199

# %% [markdown]
# ## <b>Calcular valor máximo y mínimo de Total_Venta</b>
#
# Se identifica el valor más alto y el más bajo de las ventas totales.

# %%
maximo = df["Total_Venta"].max()

minimo = df["Total_Venta"].min()

print("El valor máximo es:", maximo)

print("El valor mínimo es:", minimo)
# Out:
# El valor máximo es: 20800000
# El valor mínimo es: 630000

# %% [markdown]
# ## <b>Interpretación de Resultados</b>
#
# - La media representa el promedio general de precios.
# - La mediana representa el valor central de los precios.
# - La moda representa el precio que más se repite.
# - La desviación estándar indica qué tan dispersas están las cantidades.
# - El valor máximo representa la venta más alta.
# - El valor mínimo representa la venta más baja.

# %% [markdown]
#  # <B> PUNTO 5 - FILTRADO Y ORDENAMIENTO </B>
#
# En esta sección se aplican filtros y ordenamientos sobre el DataFrame.
#
# ## <B> Mostrar productos de Tecnología </B>
#
# Se filtran únicamente los productos pertenecientes a la categoría Tecnología.

# %%
productos_tecnologia = df[df["Categoria"] == "Tecnología"]

print(productos_tecnologia)
# Out:
#                           Producto   Precio  Cantidad  Costo_Envio  \
# 0                           Laptop  3500000         4        50000
# 1                            Mouse    80000        15        10000
# 2                          Teclado   120000        10        12000
# 3                      Silla Gamer   450000         5        30000
# 4                 Escritorio Gamer   900000         3        40000
# 5                          Monitor  1100000         6        35000
# 6                        Impresora   650000         7        25000
# 7                       Cámara Web   180000        12        15000
# 8               Disco Duro Externo   320000         8        18000
# 9                      Memoria USB    45000        25         8000
# 10                          Tablet   980000         5        28000
# 11                 Celular Samsung  2200000         9        30000
# 12                  Celular iPhone  5200000         4        40000
# ...

# %% [markdown]
# ## <B> Ordenar productos de mayor a menor según Total_Venta </B>
#
# Se organizan los productos desde la venta más alta hasta la más baja.

# %%
ordenados = df.sort_values(by="Total_Venta", ascending=False)

print(ordenados)
# Out:
#                           Producto   Precio  Cantidad  Costo_Envio  \
# 12                  Celular iPhone  5200000         4        40000
# 11                 Celular Samsung  2200000         9        30000
# 45                    Laptop Gamer  5800000         3        50000
# 26                     Consola PS5  3100000         5        40000
# 0                           Laptop  3500000         4        50000
# 46                     MacBook Air  6200000         2        55000
# 27                   Xbox Series X  2900000         4        40000
# 28                 Nintendo Switch  1800000         6        30000
# 25                           Drone  3200000         3        50000
# 58                         Mini PC  1750000         5        30000
# 37                     Smart TV 50  2800000         3        45000
# 56                    Cámara GoPro  2100000         4        35000
# 53                        Gafas VR  2400000         3        45000
# ...

# %% [markdown]
# # <b> PUNTO ADICIONAL - EXPORTAR A EXCEL </b>
#
#
# En este punto se exportó el DataFrame final a un archivo Excel utilizando la función to_excel() de Pandas.
#
# Esto permite guardar toda la información procesada en un archivo .xlsx para poder abrirlo posteriormente en Microsoft Excel.

# %%
df.to_excel("Productos_Final.xlsx", index=False)

print("Archivo Excel exportado correctamente")
# Out:
# Archivo Excel exportado correctamente

# %% [markdown]
# # <B> CONCLUSIÓN </B>
#
# Durante el desarrollo de este taller logramos aplicar diferentes conceptos fundamentales del análisis de datos utilizando la librería Pandas en Python, a través de la creación y manipulación de DataFrames, aprendimos a organizar información, realizar operaciones matemáticas entre columnas y obtener resultados estadísticos de manera eficiente.
#
# También comprendimos la importancia del análisis descriptivo para interpretar datos mediante medidas como la media, mediana, moda y desviación estándar, las cuales permiten entender mejor el comportamiento de la información almacenada en el DataFrame.
#
# Además, se realizaron procesos de filtrado y ordenamiento de datos, fortaleciendo nuestras habilidades para trabajar con grandes volúmenes de información de manera organizada y precisa. Finalmente, aprendimos a exportar los resultados obtenidos a un archivo Excel, permitiendo guardar y compartir la información procesada de forma profesional.
#
# Como grupo de trabajo, este taller nos permitió fortalecer nuestros conocimientos en Python y Pandas, mejorar el trabajo colaborativo y comprender la importancia del análisis de datos dentro del área de Inteligencia Artificial y Ciencia de Datos.
